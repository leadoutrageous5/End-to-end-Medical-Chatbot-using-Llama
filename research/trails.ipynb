# %%
print("Okay")
# Out:
# Okay

# %%
from langchain import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Pinecone
import pinecone
from langchain.document_loaders import PyPDFLoader , DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.llms  import CTransformers

# %%
#Extracting data from the pdf
def load_pdf(data):
    loader = DirectoryLoader(data ,
                     glob='*.pdf',
                    loader_cls=PyPDFLoader)
    documents =loader.load()

    return documents

# %%
extracted_data = load_pdf('data/')
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/ramakrishnaparitala/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#   File "/var/folders/yv/dwndpsg104x6y4p01bk9w67r0000gn/T/ipykernel_49187/2329439660.py", line 1, in <module>
#     extracted_data = load_pdf('data/')
#   File "/var/folders/yv/dwndpsg104x6y4p01bk9w67r0000gn/T/ipykernel_49187/3466477432.py", line 6, in load_pdf
#     documents =loader.load()
#   File "/Users/ramakrishnaparitala/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/document_loaders/directory.py", line 101, in load
#     raise FileNotFoundError(f"Directory not found: '{self.path}'")
# FileNotFoundError: Directory not found: 'data/'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ramakrishnaparitala/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/pygments/styles/__init__.py", line 45, in get_style_by_name
# ModuleNotFoundError: No module named 'pygments.styles.default'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ramakrishnaparitala/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2144, in showtraceback
#   File "/Users/ramakrishnaparitala/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#   File "/Users/ramakrishnaparitala/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#   File "/Users/ramakrishnaparitala/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#   File "/Users/ramakrishnaparitala/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1063, in format_exception_as_a_whole
#   File "/Users/ramakrishnaparitala/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1114, in get_records
#   File "/Users/ramakrishnaparitala/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/pygments/styles/__init__.py", line 47, in get_style_by_name
# pygments.util.ClassNotFound: Could not find style module 'pygments.styles.default', though it should be builtin.

# %%
# extracted_data

# %%
#Create text chunks
def text_split(extracted_data):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500 , chunk_overlap = 20)
    text_chunks = text_splitter.split_documents(extracted_data)
    
    return text_chunks

# %%
text_chunks = text_split(extracted_data)
print(len(text_chunks))
# Out:
# 7020

# %%
text_chunks[0]
# Out:
# Document(metadata={'source': 'data/Medical_book.pdf', 'page': 1}, page_content='TheGALE\nENCYCLOPEDIA\nofMEDICINE\nSECOND EDITION')

# %%
#download embedding model
def download_hugging_face_embeddings():
    embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')

    return embeddings

# %%
embeddings = download_hugging_face_embeddings()
# Out:
# /var/folders/yv/dwndpsg104x6y4p01bk9w67r0000gn/T/ipykernel_18576/3136168174.py:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')

# %%
embeddings
# Out:
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# ), model_name='sentence-transformers/all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, multi_process=False, show_progress=False)

# %%
query_result = embeddings.embed_query('Hello world')
print('Lenght ' , len(query_result))
# Out:
# Lenght  384

# %%
query_result
# Out:
# [-0.03447726368904114,
#  0.03102319873869419,
#  0.006734949070960283,
#  0.0261089988052845,
#  -0.03936203196644783,
#  -0.16030246019363403,
#  0.06692399084568024,
#  -0.0064414506778120995,
#  -0.047450508922338486,
#  0.014758870005607605,
#  0.07087535411119461,
#  0.05552756413817406,
#  0.01919330097734928,
#  -0.02625131793320179,
#  -0.010109501890838146,
#  -0.026940520852804184,
#  0.022307423874735832,
#  -0.022226650267839432,
#  -0.14969263970851898,
#  -0.01749308779835701,
#  0.007676230277866125,
#  0.054352328181266785,
#  0.003254461335018277,
#  0.031725965440273285,
#  -0.08462142199277878,
#  -0.029405977576971054,
#  0.05159567669034004,
#  0.0481240376830101,
#  -0.003314798232167959,
#  -0.05827917903661728,
#  0.04196927323937416,
#  0.022210724651813507,
#  0.12818880379199982,
#  -0.022338908165693283,
#  -0.011656265705823898,
#  0.06292837113142014,
#  -0.032876305282115936,
#  -0.09122606366872787,
#  -0.031175317242741585,
#  0.052699554711580276,
#  0.04703483358025551,
#  -0.0842030718922615,
#  -0.030056171119213104,
#  -0.020744813606142998,
#  0.009517783299088478,
#  -0.003721737302839756,
#  0.007343312259763479,
#  0.039324332028627396,
#  0.09327404946088791,
#  -0.003788584843277931,
#  -0.05274207517504692,
#  -0.05805819109082222,
#  -0.0068643828853964806,
#  0.005283231846988201,
#  0.082893006503582,
#  0.019362758845090866,
#  0.006284475326538086,
#  -0.010330792516469955,
#  0.005797567777335644,
#  0.013486114330589771,
#  0.005567923653870821,
#  0.03722706437110901,
#  0.007232501171529293,
#  0.04015624150633812,
#  0.08150327205657959,
#  0.07199162989854813,
#  -0.013056167401373386,
#  -0.04288209229707718,
#  -0.011011275462806225,
#  0.004897747654467821,
#  -0.009229715913534164,
#  0.03519148379564285,
#  -0.05103500559926033,
#  -1.571437557856825e-08,
#  -0.08862441033124924,
#  0.02390933223068714,
#  -0.01623873971402645,
#  0.03170048072934151,
#  0.027284206822514534,
#  0.05246880277991295,
#  -0.047070976346731186,
#  -0.05884743481874466,
#  -0.06320824474096298,
#  0.04088851064443588,
#  0.0498279333114624,
#  0.10655167698860168,
#  -0.07450230419635773,
#  -0.012495414353907108,
#  0.01837068609893322,
#  0.03947409987449646,
#  -0.024797892197966576,
#  0.014516244642436504,
#  -0.037069205194711685,
#  0.020015733316540718,
#  -4.859723412664607e-05,
#  0.009866524487733841,
#  0.024838799610733986,
#  -0.05245812609791756,
#  0.029314152896404266,
#  -0.08719191700220108,
#  -0.014499811455607414,
#  0.026019059121608734,
#  -0.018746402114629745,
#  -0.07620514184236526,
#  0.03504328429698944,
#  0.10363951325416565,
#  -0.028050530701875687,
#  0.01271818857640028,
#  -0.07632554322481155,
#  -0.01865236461162567,
#  0.024976715445518494,
#  0.0814453586935997,
#  0.06875890493392944,
#  -0.06405662000179291,
#  -0.08389390259981155,
#  0.0613623782992363,
#  -0.03354554995894432,
#  -0.10615336894989014,
#  -0.04008057713508606,
#  0.032530199736356735,
#  0.07662484794855118,
#  -0.07301613688468933,
#  0.0003376144450157881,
#  -0.040871575474739075,
#  -0.07578855007886887,
#  0.027527663856744766,
#  0.07462543994188309,
#  0.017717313021421432,
#  0.09121843427419662,
#  0.11022018641233444,
#  0.0005698199383914471,
#  0.051463332027196884,
#  -0.01455132570117712,
#  0.03323201462626457,
#  0.02379225194454193,
#  -0.022889820858836174,
#  0.038937538862228394,
#  0.03020678646862507]

# %%
vectors = [
    {
        "id": f"chunk-{i+1}",  # Unique ID
        "values": embeddings.embed_query(chunk.page_content),  # Embedding values
        "metadata": {"content": chunk.page_content}  # Store the original text
    }
    for i, chunk in enumerate(text_chunks)
]

print(vectors[0])
# Out:
# {'id': 'chunk-1', 'values': [0.001746108173392713, -0.03350288048386574, -0.03290396183729172, 0.007168138865381479, -0.014603259041905403, 0.010261861607432365, -0.011515265330672264, 0.22930213809013367, -0.023232368752360344, 0.004120402503758669, -0.03656088188290596, 0.08592118322849274, 0.012972164899110794, 0.05221788212656975, -0.1023261696100235, -0.00313896918669343, -0.012686862610280514, 0.000471833860501647, -0.028485817834734917, -0.050259120762348175, 0.011550931259989738, 0.0778065025806427, 0.09282825142145157, -0.013797289691865444, -0.016935057938098907, -0.025955844670534134, -0.04956505820155144, -0.04613131657242775, 0.007290530484169722, -0.013553212396800518, 0.038439445197582245, 0.06280474364757538, 0.018353790044784546, 0.008242824114859104, 0.0017155685927718878, -0.039861809462308884, -0.011638646014034748, 0.01644628308713436, 0.025595
# Pinecone API Key: 5cd2d9ee-4e85-4068-98e4-7a9b3ee4f643

# %%
# Now connecting with Vector DataBase : Pinecone and then storing the vectors we got above.
from pinecone import Pinecone

pc = Pinecone(api_key=api_key)
index_name = "medical-chatbot"
index = pc.Index(index_name)

# #Adding or Store the Vectors to above index
# # Upsert vectors to Pinecone
# index.upsert(vectors=vectors, namespace="ns1")

# %% [markdown]
# We are not send the whole Vectors at time... we will be sending in batchs so that it will be under limit

# %%
print(index.describe_index_stats())
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0,
#  'namespaces': {'ns1': {'vector_count': 7020}},
#  'total_vector_count': 7020}

# %%
from langchain.vectorstores import Pinecone
retriever = Pinecone.from_existing_index(index_name=index_name, embedding=embeddings)


# Query the index
query_vector = embeddings.embed_query("What are allergies?")
print("Query Vector:", query_vector)

response = index.query(
    vector=query_vector,
    top_k=3,
    namespace="ns1",
    include_metadata=True
)
print("Raw Pinecone Response:", response)

# Check LangChain retriever
results = retriever.similarity_search("What are allergies?")
print("LangChain Results:", results)
# Out:
# Query Vector: [0.025319892913103104, -0.004025820642709732, 0.029314134269952774, -0.005236376076936722, 0.06898462772369385, 0.03483610972762108, 0.0766669362783432, 0.02796238474547863, -0.05992485210299492, 0.06146517023444176, 0.04583435505628586, -0.07631244510412216, 0.018933532759547234, 0.03337517008185387, -0.0391276516020298, 0.08984296768903732, -0.03980489820241928, -0.01740577258169651, -0.0010402323678135872, -0.06232181563973427, 0.017125090584158897, 0.09288167953491211, -0.01691155880689621, -0.0016694372752681375, -0.026571134105324745, 0.06521008908748627, -0.02543237805366516, -0.0764322429895401, -0.0567757710814476, -0.040036678314208984, -0.0563729889690876, -0.02457081526517868, -0.005484601017087698, 0.03991376981139183, -0.04513121768832207, 0.0009315914940088987, -0.045972295105457306, 0.022260356694459915, 0.019632574170827866, 0.016805680468678474, -0.026513950899243355, 0.016967562958598137, -0.05027284845709801, -0.038652919232845306, -0.06781821697950363, 0.048880722373723984, 0.06073097139596939, 0.00843837857246399, 0.07329724729061127, 0.023983968421816826, 0.07202786952257156, -0.02342938259243965, -0.028320929035544395, -0.034133680164813995, 0.08483690768480301, -0.06955058872699738, -0.1070399209856987, -0.0723172128200531, -0.01674475334584713, -0.03702571615576744, -0.03267888352274895, -0.025751624256372452, 0.0010013531427830458, 0.05697653815150261, 0.013332594186067581, -0.01394055038690567, 0.026269910857081413, 0.12939640879631042, 0.0725773274898529, -0.004374195821583271, -0.09649325907230377, -0.036979835480451584, -0.014613496139645576, 0.09226328134536743, 0.10214152187108994, -0.04392055422067642, -0.02009277231991291, -0.047778692096471786, -0.007203472778201103, -0.00018057515262626112, -0.08204212784767151, -0.03323080763220787, 0.04566820710897446, 0.0030005224980413914, 0.06554052233695984, -0.00924172904342413, -0.017748786136507988, 0.06602859497070312, 0.025564024224877357, -0.02535577118396759, 0.039759524166584015, -0.08837618678808212, -0.04984421283006668, 0.052534498274326324, 0.03245805576443672, -0.0010249799815937877, 0.043124970048666, -0.045889485627412796, -0.028056474402546883, -0.0042799776419997215, -0.03060911037027836, -0.13572590053081512, 0.06269297748804092, 0.03405023738741875, 0.05268247798085213, 0.060473453253507614, 0.026448829099535942, -0.1433705985546112, -0.013449911028146744, 0.0041563855484128, -0.031989604234695435, 0.021543653681874275, 0.026075497269630432, 0.010713610798120499, -0.03484001010656357, -0.045207858085632324, 0.10319007188081741, -0.052840400487184525, 0.017156176269054413, 0.044763363897800446, -0.028097737580537796, -0.06500409543514252, 0.0054420470260083675, 0.002874211873859167, -0.010099126026034355, 0.04391900449991226, -0.11923394352197647, -5.6000932908837794e-33, 0.010114156641066074, 0.029299167916178703, 0.027986841276288033, 0.048476796597242355, 0.007671597879379988, 9.986117947846651e-05, 0.044623952358961105, -0.007678611669689417, 0.08286561816930771, 0.09566660970449448, -0.046417925506830215, 0.054040342569351196, -0.04318231716752052, 0.04236002266407013, 0.042965132743120193, 0.015310176648199558, -0.09117227047681808, -0.0008253958658315241, 0.013431510888040066, -0.051802463829517365, -0.12179257720708847, 0.09997721016407013, -0.07819754630327225, 0.06114867329597473, -0.0679008737206459, 0.03846735507249832, -0.00568191846832633, 0.0041644214652478695, -0.0029201435390859842, -0.050126779824495316, 0.03905453532934189, 0.02110888622701168, -0.03565089404582977, 0.04406069591641426, -0.0055226488038897514, -0.0012336323270574212, -0.014011934399604797, 0.07236868888139725, -0.01811879314482212, -0.043304700404405594, -0.07770732790231705, -0.047097478061914444, -0.06944097578525543, -0.03204282000660896, 0.001522331265732646, -0.028016472235322, -0.1271457076072693, 0.006114843301475048, -0.01124271098524332, 0.02141105756163597, 0.07142727077007294, -0.08972626179456711, -0.028937306255102158, -0 ...
# Raw Pinecone Response: {'matches': [{'id': 'chunk-1438',
#               'metadata': {'content': 'the itchy, scratchy nose, eyes, and '
#                                       'throat common inallergic rhinitis .\n'
#                                       'The particular allergens to which a '
#                                       'person is sensi-'},
#               'score': 0.69554776,
#               'values': []},
#              {'id': 'chunk-1373',
#               'metadata': {'content': 'GALE ENCYCLOPEDIA OF MEDICINE 2 '
#                                       '117Allergies\n'
#                                       'Allergic rhinitis is commonly triggered '
#                                       'by\n'
#                                       'exposure to household dust, animal '
#                                       'fur,or pollen. The foreign substance '
#                                       'thattriggers an allergic reaction is '
#                                       'calledan allergen.\n'
#                                       'The presence of an allergen causes the\n'
#                                       "body's lymphocytes to begin "
#                                       'producingIgE antibodies. The '
#                                       'lymphocytes of an allergy sufferer '
#                                       'produce an unusuallylarge amount of '
#                                       'IgE.\n'
#                                       'IgE molecules attach to mast\n'
#                                       'cells, which contain '
#                                       'histamine.HistaminePollen grains\n'
#                                       'Lymphocyte\n'
#                                       'FIRST EXPOSURE'},
#               'score': 0.694514334,
#               'values': []},
#              {'id': 'chunk-1356',
#               'metadata': {'content': 'allergens are the following:\n'
#                                       '• plant pollens\n'
#                                       '• animal fur and dander\n'
#                                       '• body parts from house mites '
#                                       '(microscopic creatures\n'
#                                       'found in all houses)\n'
#                                       '• house dust• mold spores• cigarette '
#                                       'smoke• solvents• cleaners\n'
#                                       'Common food allergens include the '
#                                       'following:\n'
#                                       '• nuts, especially peanuts, walnuts, '
#                                       'and brazil nuts\n'
#                                       '• fish, mollusks, and shellfish• eggs• '
#                                       'wheat• milk• food additives and '
#                                       'preservatives\n'
#                                       'The following types of drugs commonly '
#                                       'cause aller-\n'
#                                       'gic reactions:\n'
#                                       '• penicillin or other antibiotics'},
#               'score': 0.678800941,
#               'values': []}],
#  'namespace': 'ns1',
#  'usage': {'read_units': 6}}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 18
#      15 print("Raw Pinecone Response:", response)
#      17 # Check LangChain retriever
# ---> 18 results = retriever.similarity_search(query_vector)
#      19 print("LangChain Results:", results)
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_community/vectorstores/pinecone.py:234, in Pinecone.similarity_search(self, query, k, filter, namespace, **kwargs)
#     215 def similarity_search(
#     216     self,
#     217     query: str,
#    (...)
#     221     **kwargs: Any,
#     222 ) -> List[Document]:
#     223     """Return pinecone documents most similar to query.
#     224
#     225     Args:
#    (...)
#     232         List of Documents most similar to the query and score for each
#     233     """
# --> 234     docs_and_scores = self.similarity_search_with_score(
#     235         query, k=k, filter=filter, namespace=namespace, **kwargs
#     236     )
#     237     return [doc for doc, _ in docs_and_scores]
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_community/vectorstores/pinecone.py:180, in Pinecone.similarity_search_with_score(self, query, k, filter, namespace)
#     161 def similarity_search_with_score(
#     162     self,
#     163     query: str,
#    (...)
#     166     namespace: Optional[str] = None,
#     167 ) -> List[Tuple[Document, float]]:
#     168     """Return pinecone documents most similar to query, along with scores.
#     169
#     170     Args:
#    (...)
#     177         List of Documents most similar to the query and score for each
#     178     """
#     179     return self.similarity_search_by_vector_with_score(
# --> 180         self._embed_query(query), k=k, filter=filter, namespace=namespace
#     181     )
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_community/vectorstores/pinecone.py:98, in Pinecone._embed_query(self, text)
#      96 """Embed query text."""
#      97 if isinstance(self._embedding, Embeddings):
# ---> 98     return self._embedding.embed_query(text)
#      99 return self._embedding(text)
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_community/embeddings/huggingface.py:130, in HuggingFaceEmbeddings.embed_query(self, text)
#     121 def embed_query(self, text: str) -> List[float]:
#     122     """Compute query embeddings using a HuggingFace transformer model.
#     123
#     124     Args:
#    (...)
#     128         Embeddings for the text.
#     129     """
# --> 130     return self.embed_documents([text])[0]
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_community/embeddings/huggingface.py:109, in HuggingFaceEmbeddings.embed_documents(self, texts)
#      99 """Compute doc embeddings using a HuggingFace transformer model.
#     100
#     101 Args:
#    (...)
#     105     List of embeddings, one for each text.
#     106 """
#     107 import sentence_transformers
# --> 109 texts = list(map(lambda x: x.replace("\n", " "), texts))
#     110 if self.multi_process:
#     111     pool = self.client.start_multi_process_pool()
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_community/embeddings/huggingface.py:109, in HuggingFaceEmbeddings.embed_documents.<locals>.<lambda>(x)
#      99 """Compute doc embeddings using a HuggingFace transformer model.
#     100
#     101 Args:
#    (...)
#     105     List of embeddings, one for each text.
#     106 """
#     107 import sentence_transformers
# --> 109 texts = list(map(lambda x: x.replace("\n", " "), texts))
#     110 if self.multi_process:
#     111     pool = self.client.start_multi_process_pool()
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
# Out:
# []

# %% [markdown]
# Now I don't have to upsert the data to Pine again after doing it once.

# %%
# batch_size = 500  # Number of vectors per batch
# for i in range(0, len(vectors), batch_size):
#     batch = vectors[i:i+batch_size]
#     index.upsert(vectors=batch, namespace="ns1")
#     print(f"Upserted batch {i // batch_size + 1}")

# %%
import sys
batch_size = 500
# Calculate the size of a batch
batch = vectors[0:batch_size]
print(f"Batch size in bytes: {sys.getsizeof(batch)}")
# Out:
# Batch size in bytes: 4056

# %%
# Example query vector (embedding from the same model)
query_vector = embeddings.embed_query("What are allergies")

response = index.query(
    namespace="ns1",
    vector=query_vector,
    top_k=3,
    include_values=True,  # Include the embedding values if needed
    include_metadata=True  # Retrieve the stored text or metadata
)

# Print the response
print(response)
# Out:
# {'matches': [{'id': 'chunk-1373',
#               'metadata': {'content': 'GALE ENCYCLOPEDIA OF MEDICINE 2 '
#                                       '117Allergies\n'
#                                       'Allergic rhinitis is commonly triggered '
#                                       'by\n'
#                                       'exposure to household dust, animal '
#                                       'fur,or pollen. The foreign substance '
#                                       'thattriggers an allergic reaction is '
#                                       'calledan allergen.\n'
#                                       'The presence of an allergen causes the\n'
#                                       "body's lymphocytes to begin "
#                                       'producingIgE antibodies. The '
#                                       'lymphocytes of an allergy sufferer '
#                                       'produce an unusuallylarge amount of '
#                                       'IgE.\n'
#                                       'IgE molecules attach to mast\n'
#                                       'cells, which contain '
#                                       'histamine.HistaminePollen grains\n'
#                                       'Lymphocyte\n'
#                                       'FIRST EXPOSURE'},
#               'score': 0.682538927,
#               'values': [0.035471946,
#                          -0.0110477973,
#                          0.0751324,
#                          0.00805774517,
#                          0.113756716,
#                          0.0377156436,
#                          0.113712095,
#                          0.084044,
#                          -0.0305278637,
#                          0.0913646817,
#                          0.0113535859,
#                          -0.0614714511,
#                          0.0239176825,
#                          0.0503650866,
#                          -0.013136181,
#                          0.0664992556,
#                          -0.0492044874,
#                          -0.0601874217,
#                          -0.0266646743,
#                          -0.0484286137,
#                          0.00717466418,
#                          0.0825395435,
#                          -0.0148053179,
#                          -0.0382492468,
#                          -0.0054582539,
#                          -0.0307581779,
#                          0.00108100474,
#                          -0.0633153543,
#                          0.0174041931,
#                          -0.00629851548,
#                          0.0463763699,
#                          -0.0775860399,
#                          -0.0430283248,
#                          0.0119536594,
#                          -0.0454279557,
#                          -0.0476343744,
#                          -0.052879665,
#                          0.00680467859,
#                          0.0456809662,
#                          0.0484941863,
#                          -0.0204564538,
#                          -0.0193420909,
#                          -0.0131235076,
#                          -0.0635296777,
#                          -0.0483340397,
#                          0.00325491093,
#                          0.00788763817,
#                          0.0942979,
#                          0.0666583255,
#                          0.00820386,
#                          0.0520341061,
#                          0.0117880898,
#                          0.0407249294,
#                          -0.0372746736,
#                          -0.019957792,
#                          -0.0346242115,
#                          -0.054777164,
#                          -0.0325018279,
#                          -0.035749536,
#                          -0.034656994,
#                          -0.0774970129,
#                          -0.0298128333,
#                          -0.00479456084,
#                          -0.0038134458,
#                          0.0406014025,
#                          -0.0289424267,
#                          0.0275693201,
#                          0.106912538,
#                          0.0918054134,
#                          0.0249587558,
#                          0.0226153,
#                          -0.0610227659,
#                          -0.0118514178,
#                          0.0703599453,
#                          0.134350777,
#                          0.000748821592,
#                          0.0824889317,
#                          -0.0712787881,
#                          -0.0137179187,
#                          0.0205793511,
#                          -0.0477677658,
#                          -0.0626156926,
#                          -0.145924643,
#                          0.0311803035,
#                          0.12045528,
#                          -0.0878651887,
#                          0.119274564,
#                          -0.0745480135,
#                          -0.0571345575,
#                          0.0327597633,
#                          0.0189122092,
#                          -0.0291731153,
#                          -0.0208106097,
#                          -0.0606677942,
#                          -0.0545089245,
#                          -0.0484828204,
#                          0.0462429821,
#                          -0.00445169304,
#                          -0.0503002219,
#                          0.0156010743,
#                          0.012886419,
#                          -0.0346729,
#                          -0.0826353729,
#                          -0.0506449305,
#                          -0.0425090455,
#                          -0.0121338787,
#                          0.0962994397,
#                          -0.0428316742,
#                          0.043850258,
#                          -0.030156929,
#                          -0.0434121117,
#                          0.0835778937]},
#              {'id': 'chunk-1356',
#               'metadata': {'content': 'allergens are the following:\n'
#                                       '• plant pollens\n'
#                                       '• animal fur and dander\n'
#                                       '• body parts from house mites '
#                                       '(microscopic creatures\n'
#                                       'found in all houses)\n'
#                                       '• house dust• mold spores• cigarette '
#                                       'smoke• solvents• cleaners\n'
#                                       'Common food allergens include the '
#                                       'following:\n'
#                                       '• nuts, especially peanuts, walnuts, '
#                                       'and brazil nuts\n'
#                                       '• fish, mollusks, and shellfish• eggs• '
#                                       'wheat• milk• food additives and '
#                                       'preservatives\n'
#                                       'The following types of drugs commonly '
#                                       'cause aller-\n'
#                                       'gic reactions:\n'
#                                       '• penicillin or other antibiotics'},
#               'score': 0.678439796,
#               'values': [-0.0209609345,
#                          -0.0801674128,
#                          0.0801562667,
#                          0.0109158838,
#                          0.0979334,
#                          0.0350946188,
#                          0.00499417912,
#                          0.0901781693,
#                          -0.0215412937,
#                          0.11007908,
#                          0.0629453585,
#                          -0.00376178883,
#                          -0.032607045,
#                          0.0154997865,
#                          -0.00482342858,
#                          0.0368017554,
#                          0.0144975474,
#                          -0.0129090901,
#                          0.04464956,
#                          0.0346062258,
#                          0.00290037133,
#                          0.110080414,
#                          0.0171310548,
#                          0.0348968767,
#                          -0.0403505415,
#                          0.0565532222,
#                          -0.000847485906,
#                          -0.105289266,
#                          -0.0196913909,
#                          -0.0501724817,
#                          -0.00630788738,
#                          -0.00516665,
#                          0.0111646838,
#                          0.0306801666,
#                          0.00471340865,
#                          -0.0100172488,
#                          -0.0593366362,
#                          -0.0307963099,
#                          0.0903923,
#                          0.0450309776,
#                          0.00724241417,
#                          -0.0495326482,
#                          -0.0485128611,
#                          -0.0493379869,
#                          -0.0719052,
#                          0.0181582402,
#                          0.0194500647,
#                          -0.0179803967,
#                          0.0580780879,
#                          0.000311407086,
#                          0.0515984409,
#                          -0.00124086009,
#                          0.00374468556,
#                          -0.0158824828,
#                          0.065985553,
#                          -0.0946703404,
#                          -0.066091381,
#                          -0.0505895875,
#                          0.0054738326,
#                          -0.00247431174,
#                          -0.0566999055,
#                          -0.0164976101,
#                          0.00749962451,
#                          -0.0320385136,
#                          -0.0191743523,
#                          0.0116926953,
#                          0.0158629175,
#                          -0.0241129771,
#                          -0.0127609307,
#                          -0.0953225121,
#                          -0.00460011745,
#                          -0.00656131,
#                          -0.0287186056,
#                          0.0128425537,
#                          -0.0191607606,
#                          0.0439891629,
#                          0.0568591356,
#                          0.0667327419,
#                          0.025672555,
#                          0.0645759702,
#                          -0.0461879969,
#                          -0.0585441,
#                          -0.103770524,
#                          -0.0256061815,
#                          3.54178774e-05,
#                          0.0222698841,
#                          -0.0708425343,
#                          0.0804772303,
#                          0.0411345,
#                          -0.0525465235,
#                          0.0136886714,
#                          -0.0698397607,
#                          -0.03904818,
#                          -0.040098682,
#                          -0.0152611304,
#                          -0.0458761752,
#                          -0.0248246938,
#                          0.0374103,
#                          0.0044443924,
#                          0.0143120354,
#                          0.0402721055,
#                          -0.019584775,
#                          -0.0637246668,
#                          -0.118985683,
#                          0.0273564812,
#                          0.0974644423,
#                          -0.0307523981,
#                          0.0765570402,
#                          -0.138123363,
#                          0.0134081347,
#                          -0.0141164735,
#                          -0.0182010811,
#                          0.121987849]},
#              {'id': 'chunk-1306',
#               'metadata': {'content': 'itchy, scratchy nose, eyes, and throat '
#                                       'common in aller-gic rhinitis.\n'
#                                       'The number of possible airborne '
#                                       'allergens is enor-'},
#               'score': 0.677086294,
#               'values': [-0.0306381229,
#                          -0.122239821,
#                          0.0301396698,
#                          -0.0118640754,
#                          0.0762755275,
#                          0.0190069284,
#                          0.0419997498,
#                          0.0386011675,
#                          -0.0707131773,
#                          0.0692529,
#                          0.0159991886,
#                          -0.0593805611,
#                          0.0505229905,
#                          0.0961162373,
#                          -0.0102464464,
#                          0.0253130924,
#                          -0.00321651134,
#                          -0.0875126496,
#                          0.0243905894,
#                          -0.0484199934,
#                          -0.00576061523,
#                          0.151099265,
#                          0.0119996807,
#                          -0.043120347,
#                          0.00912601687,
#                          0.00537837297,
#                          -0.00962683745,
#                          -0.0488767214,
#                          -0.046443779,
#                          -0.046219945,
#                          -0.0559057333,
#                          -0.0606495552,
#                          0.00491329841,
#                          0.0335321687,
#                          0.00318694324,
#                          -0.00164197676,
#                          -0.0337263122,
#                          0.0401967354,
#                          0.0671067163,
#                          0.0412696414,
#                          -0.0590047762,
#                          0.0513369329,
#                          -0.0527532473,
#                          -0.0415924788,
#                          -0.0926619172,
#                          0.0391939953,
#                          -0.0010436771,
#                          0.0226122104,
#                          0.0818409547,
#                          -0.0023876729,
#                          0.0471629873,
#                          -0.0355953313,
#                          0.014173205,
#                          -0.0174854547,
#                          0.012276317,
#                          -0.0319536,
#                          -0.0583052151,
#                          -0.109036125,
#                          -0.0476507172,
#                          -0.0296828132,
#                          -0.0845378488,
#                          -0.0282572564,
#                          0.045782052,
#                          -0.0011016205,
#                          0.0299371369,
#                          0.0352304913,
#                          -0.000187658705,
#                          0.0889853239,
#                          0.0989147946,
#                          0.0595468581,
#                          0.000592078082,
#                          -0.0389381312,
#                          -0.0540971,
#                          0.0533025227,
#                          0.0148135098,
#                          -0.0081245983,
#                          -0.020902995,
#                          -0.0586473718,
#                          0.0226197131,
#                          0.0416291319,
#                          0.00251930207,
#                          -0.0341368578,
#                          -0.0801914781,
#                          -0.0837235153,
#                          0.0409504101,
#                          0.0592205338,
#                          -0.021545168,
#                          0.0778022259,
#                          -0.00485351123,
#                          -0.081218183,
#                          -0.0166929699,
#                          -0.00427679904,
#                          0.00883962587,
#                          -0.0874924436,
#                          -0.0318980925,
#                          -0.0613928586,
#                          -0.0628123879,
#                          0.0414005071,
#                          0.00925500877,
#                          -0.00401233463,
#                          0.0465459935,
#                          -0.0341602452,
#                          0.0342391208,
#                          -0.0631002858,
#                          -0.00383389788,
#                          -0.00499792816,
#                          -0.0253718849,
#                          0.0258528572,
#                          -0.052539669,
#                          -0.0147622162,
#                          -0.0743564665,
#                          -0.124624141,
#                          0.0345892049]}],
#  'namespace': 'ns1',
#  'usage': {'read_units': 6}}

# %%
# Access the results
for match in response["matches"]:
    text = match["metadata"]["content"]  # Retrieve the text
    score = match["score"]  # Retrieve the similarity score
    print(f"Text: {text}, Score: {score}")
# Out:
# Text: GALE ENCYCLOPEDIA OF MEDICINE 2 117Allergies
# Allergic rhinitis is commonly triggered by
# exposure to household dust, animal fur,or pollen. The foreign substance thattriggers an allergic reaction is calledan allergen.
# The presence of an allergen causes the
# body's lymphocytes to begin producingIgE antibodies. The lymphocytes of an allergy sufferer produce an unusuallylarge amount of IgE.
# IgE molecules attach to mast
# cells, which contain histamine.HistaminePollen grains
# Lymphocyte
# FIRST EXPOSURE, Score: 0.682538927
# Text: allergens are the following:
# • plant pollens
# • animal fur and dander
# • body parts from house mites (microscopic creatures
# found in all houses)
# • house dust• mold spores• cigarette smoke• solvents• cleaners
# Common food allergens include the following:
# • nuts, especially peanuts, walnuts, and brazil nuts
# • fish, mollusks, and shellfish• eggs• wheat• milk• food additives and preservatives
# The following types of drugs commonly cause aller-
# gic reactions:
# • penicillin or other antibiotics, Score: 0.678439796
# Text: itchy, scratchy nose, eyes, and throat common in aller-gic rhinitis.
# The number of possible airborne allergens is enor-, Score: 0.677086294

# %%
prompt_template= """ 
Use the following pieces of information to answer the user's question.
If you don't know the answer , just say that you don't know , don't try to make up an answer.
Context: {context}
Question: {question}

Only return teh helpful answer below and nothing else
Helpful Answer:
"""

# %%
PROMPT= PromptTemplate(template= prompt_template , input_variables=['context' , 'question'])
chain_type_kwargs={'prompt': PROMPT}

# %%
llm = CTransformers(model ="model/llama-2-7b-chat.ggmlv3.q2_K.bin" ,
                    model_type = 'llama',
                     config= {'max_new_tokens' :512 ,
                              'temperature': 0.8} )

# %%
from langchain.vectorstores import Pinecone
from langchain.chains import RetrievalQA

# Initialize the Pinecone retriever with the embeddings
retriever = Pinecone.from_existing_index(index_name=index_name, embedding=embeddings)

# %%
# Create the RetrievalQA chain with the customizations
qa = RetrievalQA.from_chain_type(
    llm=llm,                      # Your LLM model (CTransformers in this case)
    retriever=retriever.as_retriever(search_kwargs={"k": 3}),  # Limit to 3 documents
    chain_type="stuff",            # Chain type, change to "stuff" or other options if necessary
    return_source_documents=True,  # Ensure source documents are returned
    chain_type_kwargs=chain_type_kwargs  # Include source document metadata
)

# %%
# Run the query
query = "What are allergies?"
response = qa.invoke(query)

# Print the response and the source documents
print("Response:", response['result'])  # Response answer from LLM
print("Source Documents:", response['source_documents'])  # Retrieved documents
# Out:
# Response: An allergy is a reaction by your immune system to a usually harmless substance called an allergen. It can cause a variety of symptoms including sneezing, itchy eyes, runny nose, stomach problems, and in severe cases, life-threatening reactions like anaphylaxiss
# Allergies can occur at any age but are most common among children and young adults. Treatment consists of avoidance of the allergen and medications such as antihistamines or corticosteroids to manage symptoms.
# Please let me know if you would like me to answer any other questions.
# Source Documents: []

# %%
while True:
    user_input = input(f'Input Prompt')
    result= qa({'query': user_input})
    print("Response: " , result['result'])
# Out:
# /var/folders/yv/dwndpsg104x6y4p01bk9w67r0000gn/T/ipykernel_18576/3602657672.py:3: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result= qa({'query': user_input})
# Response:  Acne is a common skin condition that occurs when hair follicles on the face, nose, forehead, and other areas of the body become clogged with excess oil (sebum) and dead skin cells.
# It may appear as bumps or pimples. There are different types of acne including comedones (whiteheads and blackheads), papules, pustules, nodules and in some cases, it can lead to scarring of the skin.
# Acne is a chronic condition, meaning that it can persist over time unless treated. It is also important to note that acne is not caused by poor hygiene or diet, but rather by complex interactions between genetic, hormonal and environmental factors.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 3
#       1 while True:
#       2     user_input = input(f'Input Prompt')
# ----> 3     result= qa({'query': user_input})
#       4     print("Response: " , result['result'])
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)
#     380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/retrieval_qa/base.py:154, in BaseRetrievalQA._call(self, inputs, run_manager)
#     152 else:
#     153     docs = self._get_docs(question)  # type: ignore[call-arg]
# --> 154 answer = self.combine_documents_chain.run(
#     155     input_documents=docs, question=question, callbacks=_run_manager.get_child()
#     156 )
#     158 if self.return_source_documents:
#     159     return {self.output_key: answer, "source_documents": docs}
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/base.py:611, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     606     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     607         _output_key
#     608     ]
#     610 if kwargs and not args:
# --> 611     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     612         _output_key
#     613     ]
#     615 if not kwargs and not args:
#     616     raise ValueError(
#     617         "`run` supported with either positional arguments or keyword arguments,"
#     618         " but none were provided."
#     619     )
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)
#     380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/combine_documents/base.py:138, in BaseCombineDocumentsChain._call(self, inputs, run_manager)
#     136 # Other keys are assumed to be needed for LLM prediction
#     137 other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 138 output, extra_return_dict = self.combine_docs(
#     139     docs, callbacks=_run_manager.get_child(), **other_keys
#     140 )
#     141 extra_return_dict[self.output_key] = output
#     142 return extra_return_dict
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/combine_documents/stuff.py:259, in StuffDocumentsChain.combine_docs(self, docs, callbacks, **kwargs)
#     257 inputs = self._get_inputs(docs, **kwargs)
#     258 # Call predict on the LLM.
# --> 259 return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/llm.py:318, in LLMChain.predict(self, callbacks, **kwargs)
#     303 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     304     """Format prompt with kwargs and pass to LLM.
#     305
#     306     Args:
#    (...)
#     316             completion = llm.predict(adjective="funny")
#     317     """
# --> 318     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)
#     380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/llm.py:126, in LLMChain._call(self, inputs, run_manager)
#     121 def _call(
#     122     self,
#     123     inputs: Dict[str, Any],
#     124     run_manager: Optional[CallbackManagerForChainRun] = None,
#     125 ) -> Dict[str, str]:
# --> 126     response = self.generate([inputs], run_manager=run_manager)
#     127     return self.create_outputs(response)[0]
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain/chains/llm.py:138, in LLMChain.generate(self, input_list, run_manager)
#     136 callbacks = run_manager.get_child() if run_manager else None
#     137 if isinstance(self.llm, BaseLanguageModel):
# --> 138     return self.llm.generate_prompt(
#     139         prompts,
#     140         stop,
#     141         callbacks=callbacks,
#     142         **self.llm_kwargs,
#     143     )
#     144 else:
#     145     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     146         cast(List, prompts), {"callbacks": callbacks}
#     147     )
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_core/language_models/llms.py:755, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     747 def generate_prompt(
#     748     self,
#     749     prompts: list[PromptValue],
#    (...)
#     752     **kwargs: Any,
#     753 ) -> LLMResult:
#     754     prompt_strings = [p.to_string() for p in prompts]
# --> 755     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_core/language_models/llms.py:950, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     935 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     936     run_managers = [
#     937         callback_manager.on_llm_start(
#     938             self._serialized,
#    (...)
#     948         )
#     949     ]
# --> 950     output = self._generate_helper(
#     951         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     952     )
#     953     return output
#     954 if len(missing_prompts) > 0:
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_core/language_models/llms.py:792, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     790     for run_manager in run_managers:
#     791         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 792     raise e
#     793 flattened_outputs = output.flatten()
#     794 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_core/language_models/llms.py:779, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     769 def _generate_helper(
#     770     self,
#     771     prompts: list[str],
#    (...)
#     775     **kwargs: Any,
#     776 ) -> LLMResult:
#     777     try:
#     778         output = (
# --> 779             self._generate(
#     780                 prompts,
#     781                 stop=stop,
#     782                 # TODO: support multiple run managers
#     783                 run_manager=run_managers[0] if run_managers else None,
#     784                 **kwargs,
#     785             )
#     786             if new_arg_supported
#     787             else self._generate(prompts, stop=stop)
#     788         )
#     789     except BaseException as e:
#     790         for run_manager in run_managers:
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_core/language_models/llms.py:1502, in LLM._generate(self, prompts, stop, run_manager, **kwargs)
#    1499 new_arg_supported = inspect.signature(self._call).parameters.get("run_manager")
#    1500 for prompt in prompts:
#    1501     text = (
# -> 1502         self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1503         if new_arg_supported
#    1504         else self._call(prompt, stop=stop, **kwargs)
#    1505     )
#    1506     generations.append([Generation(text=text)])
#    1507 return LLMResult(generations=generations)
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/langchain_community/llms/ctransformers.py:104, in CTransformers._call(self, prompt, stop, run_manager, **kwargs)
#     102 text = []
#     103 _run_manager = run_manager or CallbackManagerForLLMRun.get_noop_manager()
# --> 104 for chunk in self.client(prompt, stop=stop, stream=True):
#     105     text.append(chunk)
#     106     _run_manager.on_llm_new_token(chunk, verbose=self.verbose)
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/ctransformers/llm.py:570, in LLM._stream(self, prompt, max_new_tokens, top_k, top_p, temperature, repetition_penalty, last_n_tokens, seed, batch_size, threads, stop, reset)
#     568 text = ""
#     569 incomplete = b""
# --> 570 for token in self.generate(
#     571     tokens,
#     572     top_k=top_k,
#     573     top_p=top_p,
#     574     temperature=temperature,
#     575     repetition_penalty=repetition_penalty,
#     576     last_n_tokens=last_n_tokens,
#     577     seed=seed,
#     578     batch_size=batch_size,
#     579     threads=threads,
#     580     reset=reset,
#     581 ):
#     582     # Handle incomplete UTF-8 multi-byte characters.
#     583     incomplete += self.detokenize([token], decode=False)
#     584     complete, incomplete = utf8_split_incomplete(incomplete)
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/ctransformers/llm.py:537, in LLM.generate(self, tokens, top_k, top_p, temperature, repetition_penalty, last_n_tokens, seed, batch_size, threads, reset)
#     528 while True:
#     529     token = self.sample(
#     530         top_k=top_k,
#     531         top_p=top_p,
#    (...)
#     535         seed=seed,
#     536     )
# --> 537     self.eval([token], batch_size=batch_size, threads=threads)
#     538     if self.is_eos_token(token):
#     539         break
#
# File ~/Desktop/End-to-end-Medical-Chatbot-using-Llama2/mchatbot/lib/python3.9/site-packages/ctransformers/llm.py:403, in LLM.eval(self, tokens, batch_size, threads)
#     399     logger.warning(
#     400         f"Number of tokens ({n_past + n_tokens}) exceeded maximum context length ({self.context_length})."
#     401     )
#     402 tokens = (c_int * n_tokens)(*tokens)
# --> 403 status = self.ctransformers_llm_batch_eval(
#     404     tokens,
#     405     n_tokens,
#     406     n_past,
#     407     batch_size,
#     408     threads,
#     409 )
#     410 if not status:
#     411     raise RuntimeError("Failed to evaluate tokens.")
#
# KeyboardInterrupt:
